# %% [markdown]
# # Automated checkers simulator

# %% [markdown]
# Hello!
#
# I introduce to you code that automates an entire checkers game through random moves. The game is simulated using 'x' and 'o' symbols to denote black and white squares respectively. 'W' and 'B' symbols denote pawns and lowercase 'w' and 'b' symbols denote king pieces. The game ends when there are no legal moves to be made.
#
# To be entirely honest, I'm not quite sure when this would be useful as the game of checkers has been solved, you could use this to potentially:
#
# - Settle disputes as a unnessacarily complicated coinflip
# - Help inspire you to make moves that would leave an opponnent confused to say the least
# - Adjust it slightly to let you input and actually play the game with another friend
# - Analyze and be inspired by the deep complexities of a random number machine generating completely new unseen before games
#
# Features of the game:
# Moves, kinging, capturing

# %% [markdown]
# ## Project Code
#
# If it makes sense for your project, you can have code and outputs here in the notebook as well.

# %%
from my_module import functions as func

func.play_game()
# Out:
# x B x B x B x B
# B x B x B x B x
# x B x B x B x B
# o x o x o x o x
# x o x o x o x o
# W x W x W x W x
# x W x W x W x W
# W x W x W x W x
# White's move:
# x B x B x B x B
# B x B x B x B x
# x B x B x B x B
# o x o x o x o x
# x o x W x o x o
# W x W x o x W x
# x W x W x W x W
# W x W x W x W x
# Black's move:
# x B x B x B x B
# B x B x B x B x
# x o x B x B x B
# o x B x o x o x
# x o x W x o x o
# W x W x o x W x
# x W x W x W x W
# W x W x W x W x
# White's move:
# x B x B x B x B
# B x B x B x B x
# x W x B x B x B
# o x o x o x o x
# x o x o x o x o
# W x W x o x W x
# x W x W x W x W
# W x W x W x W x
# Black's move:
# x B x B x B x B
# B x o x B x B x
# x o x B x B x B
# B x o x o x o x
# x o x o x o x o
# W x W x o x W x
# x W x W x W x W
# W x W x W x W x
# White's move:
# x B x B x B x B
# B x o x B x B x
# x o x B x B x B
# B x o x o x o x
# x W x o x o x o
# W x o x o x W x
# x W x W x W x W
# W x W x W x W x
# Black's move:
# x B x B x B x B
# B x o x B x B x
# ...

# %% [markdown]
# #### Extra Credit (*optional*)
#
# Replace all of this text with a brief explanation (~3 sentences) of:
# 1. Your Python Background
# 2. How your project went above and beyond the requirements of the project and/or how you challenged yourself to learn something new with the final project

# %% [markdown]
# ####
# 1. I took a two-week summer course learning python in elementary school,
# pretty much just messing with the turtle function to create funny pictures.
# I forgot pretty much anything (if at all) that I learned. I did take AP CSA my senior year
# of highschool, which did help a lot in learning the language, up until a little bit after the first midterm. But, to be honest, a lot of coding was to simply fulfill very specific questions on the AP exam. While I don't remember too much, we never had to use anything beyond create 1-2 functions of code per assignment Having the
# freedom of simplicity was something that I enjoyed a lot.
#
#
# 2. Originally, I planned to allow inputs to move the pieces in the game,
# but I ran into some slight issue of actually getting the pieces to move
# correctly in a grid. Therefore, I went through path of completely randomly
# simulating games which probably took more effort than the original plan
# itself. I really learned A LOT about elif/abs keywords. Also, the nested for loops sent me through a lot of trouble learning and kind of learning how they worked
